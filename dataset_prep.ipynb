# %%
from dataset import test_dimensionality_reduction
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\requests\__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (5.1.0)/charset_normalizer (2.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "

# %%
test_dimensionality_reduction(components=100)
# Out:
# Explained variance ratio: [0.2907663  0.11253144 0.06694414 0.03676459 0.03608843 0.0280923
#  0.02712992 0.02167162 0.02064641 0.01438001 0.01310563 0.01065978
#  0.01049981 0.01004269 0.00918482 0.008174   0.00739608 0.0071613
#  0.00687472 0.00643243 0.00594396 0.00587355 0.00495567 0.00490792
#  0.00480452 0.00465877 0.00451348 0.00443654 0.00400781 0.00393866
#  0.00366217 0.0033314  0.00323965 0.00310246 0.00307587 0.0029125
#  0.00261219 0.00259261 0.00254345 0.00248378 0.00242671 0.0022932
#  0.00228175 0.00221518 0.0021026  0.00206732 0.00192457 0.00190379
#  0.0018466  0.00181696 0.00178052 0.001736   0.00171165 0.00169759
#  0.00162334 0.0015859  0.00156412 0.00154301 0.00153092 0.00149923
#  0.00145784 0.00142325 0.00141115 0.00137706 0.00134852 0.00132665
#  0.00128841 0.00124305 0.00121384 0.00121196 0.00118523 0.00116828
#  0.00113989 0.00112291 0.00111654 0.00111018 0.00110281 0.00104793
#  0.00103624 0.00101704 0.00099874 0.00098827 0.00097782 0.00097149
# ...

# %% [markdown]
# ### We can see that with `100` components, we are getting `90%` of the data but the variance ratio reduces below `0.001` after `80` components.
# ### It would be wise to take `80` components as our dimensionality reduction with the total variance of `~88.3%`
